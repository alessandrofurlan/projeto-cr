# %%
import pandas as pd
df = pd.read_csv('gephi_data_nodes.csv')
df
# Out:
#     Id                       Label  timeset transferencia
# 0    0       sbc_alfa1_entrada_sul      NaN           NaN
# 1    1     sbc_delta_entrada_leste      NaN           NaN
# 2    2      sbc_beta_entrada_oeste      NaN           NaN
# 3    3        sbc_ru_entrada norte      NaN           NaN
# 4    4       sbc_delta_entrada_sul      NaN           NaN
# 5    5  sbc_elbranco_entrada_norte      NaN           NaN
# 6    6     sbc_alfa2_entrada_norte      NaN           NaN
# 7    7       sbc_omega_entrada_sul      NaN           NaN
# 8    8     sbc_omega_entrada_norte      NaN           NaN
# 9    9      sbc_areiao_entrada_sul      NaN           NaN
# 10  10    sbc_areiao_entrada_norte      NaN           NaN
# 11  11                 sbc_fretado      NaN           NaN
# 12  12          sbc_tranferencia_1      NaN          True
# 13  13         sbc_transferencia_2      NaN          True
# 14  14         sbc_transferencia_3      NaN          True
# ...

# %%
depara_temp = df.to_dict()
depara = {y:x for x,y in depara_temp["Label"].items()}
depara
# Out:
# {'sbc_alfa1_entrada_sul': 0,
#  'sbc_delta_entrada_leste': 1,
#  'sbc_beta_entrada_oeste': 2,
#  'sbc_ru_entrada norte': 3,
#  'sbc_delta_entrada_sul': 4,
#  'sbc_elbranco_entrada_norte': 5,
#  'sbc_alfa2_entrada_norte': 6,
#  'sbc_omega_entrada_sul': 7,
#  'sbc_omega_entrada_norte': 8,
#  'sbc_areiao_entrada_sul': 9,
#  'sbc_areiao_entrada_norte': 10,
#  'sbc_fretado': 11,
#  'sbc_tranferencia_1': 12,
#  'sbc_transferencia_2': 13,
#  'sbc_transferencia_3': 14,
#  'sbc_transferencia_4': 15,
#  'sbc_transferencia_5': 16,
#  'sbc_transferencia_6': 17,
#  'sbc_transferencia_7': 18,
#  'sbc_transferencia_8': 19,
#  'sbc_alfa1_entrada_norte': 20,
#  'sbc_transferencia_9': 21,
#  'sbc_transferencia_10': 22,
#  'sbc_transferencia_11': 23,
#  'sbc_transferencia_12': 24,
#  'sbc_transferencia_13': 25,
#  'sbc_transferencia_14': 26,
#  'sbc_alfa2_entrada_sul': 27}
