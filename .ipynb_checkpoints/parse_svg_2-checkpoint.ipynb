# %%
from bs4 import BeautifulSoup

def getPotintsCoordinates(fileName):
    with open(fileName, 'r') as file:
        html_doc = file.read()
        soup = BeautifulSoup(html_doc, 'html.parser')
        points = [{"id": circle['id'], "x_coordinate": float(circle['cx']), "y_coordinate": float(circle['cy']) } for circle in soup.find_all('circle') + soup.find_all('ellipse')]
        return points

# %%
pontosAlfa2Terreo = getPotintsCoordinates('Alfa1/Alfa1_terreo_sem_imagem.svg')
pontosAlfa2Andar1 = getPotintsCoordinates('Alfa1/Alfa2_1andar.svg')
pontosAlfa2Andar2 = getPotintsCoordinates('Alfa1/Alfa2_2andar.svg')
pontosAlfa2Andar3 = getPotintsCoordinates('Alfa1/Alfa2_3andar.svg')

pontosAlfa2Terreo
# Out:
# [{'id': 'entrada_alfa2_1',
#   'x_coordinate': 550.74591,
#   'y_coordinate': 255.53873},
#  {'id': 'lab_informatica_3',
#   'x_coordinate': 1169.7585,
#   'y_coordinate': 367.16397},
#  {'id': 'bedelaria', 'x_coordinate': 445.57837, 'y_coordinate': 371.77658},
#  {'id': 'Banheiro_esquerda',
#   'x_coordinate': 162.82523,
#   'y_coordinate': 371.31531},
#  {'id': 'sala_de_uso_geral_1',
#   'x_coordinate': 328.418,
#   'y_coordinate': 367.16397},
#  {'id': 'sala_de_uso_geral_2',
#   'x_coordinate': 329.80179,
#   'y_coordinate': 304.43243},
#  {'id': 'copa', 'x_coordinate': 389.3045, 'y_coordinate': 303.97116},
#  {'id': 'almoxarifado_', 'x_coordinate': 377.31171, 'y_coordinate': 360.7063},
#  {'id': 'cantina_alfa_2', 'x_coordinate': 502.31351, 'y_coordinate': 261.9964},
#  {'id': 'escadas_esquerda',
#   'x_coordinate': 572.88647,
#   'y_coordinate': 407.75494},
#  {'id': 'entrada_alfa2_2', 'x_coordinate': 801.21082, 'y_coordinate': 256.0},
#  {'id': 'lab_informatica2',
#   'x_coordinate': 1168.3748,
#   'y_coordinate': 408.67746},
#  {'id': 'banheiros_direita',
#   'x_coordinate': 1299.8342,
#   'y_coordinate': 372.6991},
#  {'id': 'sala_de_estudos_0',
#   'x_coordinate': 855.17834,
#   'y_coordinate': 367.16397},
#  {'id': 'lab_informatica_1',
#   'x_coordinate': 479.7117,
#   'y_coordinate': 407.2937},
#  {'id': 'entrada_alfa2_3',
#   'x_coordinate': 705.26843,
#   'y_coordinate': 451.57477},
#  {'id': 'escada_direita',
#   'x_coordinate': 828.42523,
#   'y_coordinate': 403.60361}]

# %%
def insereIndexCsv(lista, inicio):
    for i in range(len(lista)):
        lista[i]['index_csv'] = i + inicio

# %%
insereIndexCsv(pontosAlfa2Terreo, 28)
insereIndexCsv(pontosAlfa2Andar1, 28+len(pontosAlfa2Terreo))
insereIndexCsv(pontosAlfa2Andar2, 28+len(pontosAlfa2Terreo)+len(pontosAlfa2Andar1))
insereIndexCsv(pontosAlfa2Andar3, 28+len(pontosAlfa2Terreo)+len(pontosAlfa2Andar1)+len(pontosAlfa2Andar2))

# %%
ref_1_terreo = "sala_de_estudos_0"
ref_2_terreo = "lab_informatica_3"
ref_1_andar_1 = "Sala_de_aula_103" 
ref_2_andar_1 = "Sala_de_aula_104"
ref_1_andar_2 = "sala_de_aula_204" 
ref_2_andar_2 = "sala_de_aula_203"
ref_1_andar_3 = "sala_de_aula_302" 
ref_2_andar_3 = "sala_de_aula_304"
escalaRefTerreo =  18.7
escalaRefAndares = 7.08

# %%
import numpy as np

def getDistances(array, ref1, ref2, scale):
    indexRefer1 = array.index(list(filter(lambda x: x['id'] == ref1, array))[0])
    indexRefer2 = array.index(list(filter(lambda x: x['id'] == ref2, array))[0])
    npAr = np.array([[val["x_coordinate"], val["y_coordinate"]] for val in array])
    absDistances = np.linalg.norm(npAr - npAr[:,None], axis=-1)
    distCart = absDistances[indexRefer1][indexRefer2]
    realDistances = (scale/distCart)*absDistances
    return realDistances

# %%
distanciasTerreo = getDistances(pontosAlfa2Terreo, ref_1_terreo, ref_2_terreo, escalaRefTerreo)
distanciasAndar1 = getDistances(pontosAlfa2Andar1, ref_1_andar_1, ref_2_andar_1, escalaRefAndares)
distanciasAndar2 = getDistances(pontosAlfa2Andar2, ref_1_andar_2, ref_2_andar_2, escalaRefAndares)
distanciasAndar3 = getDistances(pontosAlfa2Andar3, ref_1_andar_3, ref_2_andar_3, escalaRefAndares)

# %%
def criaStringCsv(lista):
    for i in range(len(lista)):
       print('{},{},,'.format(lista[i]['index_csv'], lista[i]['id']))

# %%
criaStringCsv(pontosAlfa2Terreo+pontosAlfa2Andar1+pontosAlfa2Andar2+pontosAlfa2Andar3)
# Out:
# 28,entrada_alfa2_1,,
# 29,lab_informatica_3,,
# 30,bedelaria,,
# 31,Banheiro_esquerda,,
# 32,sala_de_uso_geral_1,,
# 33,sala_de_uso_geral_2,,
# 34,copa,,
# 35,almoxarifado_,,
# 36,cantina_alfa_2,,
# 37,escadas_esquerda,,
# 38,entrada_alfa2_2,,
# 39,lab_informatica2,,
# 40,banheiros_direita,,
# 41,sala_de_estudos_0,,
# 42,lab_informatica_1,,
# 43,entrada_alfa2_3,,
# 44,escada_direita,,
# 45,Sala_de_aula_106,,
# 46,sala_de_apoio,,
# 47,banheiro_direita_1a,,
# 48,Banheiro_esquerda_1a,,
# 49,sala_de_aula_102,,
# 50,Sala_de_aula_101,,
# 51,escada_direita,,
# 52,Sala_de_aula_104,,
# 53,Sala_de_aula_103,,
# 54,sala_de_aula_105,,
# 55,escada_esquerda,,
# 56,sala_de_aula_204,,
# 57,sala_de_aula_208,,
# 58,sala_de_aula_205,,
# 59,sala_de_apoio_2a,,
# 60,escada_direita_2a,,
# 61,banheiro_esquerda_2a,,
# 62,sala_de_aula_202,,
# 63,sala_de_aula_201,,
# 64,sala_de_aula_206,,
# 65,sala_de_aula_203,,
# 66,banheiro_direita_2a,,
# 67,Sala_de_estudos_2a,,
# 68,escada_esquerda_2a,,
# 69,escada_esquerda_3a,,
# 70,sala_de_aula_307,,
# 71,banheiros_esquerda_3a,,
# 72,escada_direita_3a,,
# 73,sala_de_aula_309,,
# 74,banheiros_direita_3a,,
# 75,sala_de_aula_302,,
# 76,sala_de_aula_306,,
# 77,sala_de_aula_308,,
# 78,Sala_de_estudos_3a,,
# 79,sala_de_aula_304,,
# 80,sala_de_aula_305,,

# %%
cutoff = 20
def criaAtributoDistanciaParaCsv(listaPontos, listaDistancias):
    distancias = {}
    begin = 0
    for i in range(len(listaDistancias)):
        distancias[listaPontos[i]['index_csv']] = {}
        for j in range(begin, len(listaDistancias[i])):
            if (listaDistancias[i][j] <= cutoff) and listaDistancias[i][j] > 0:
                distancias[listaPontos[i]['index_csv']][listaPontos[j]['index_csv']] = listaDistancias[i][j]
        begin += 1
        if distancias[listaPontos[i]['index_csv']] == {}:
            del distancias[listaPontos[i]['index_csv']]
    return distancias

# %%
dict_terreo = criaAtributoDistanciaParaCsv(pontosAlfa2Terreo, distanciasTerreo)
dict_andar1 = criaAtributoDistanciaParaCsv(pontosAlfa2Andar1, distanciasAndar1)
dict_andar2 = criaAtributoDistanciaParaCsv(pontosAlfa2Andar2, distanciasAndar2)
dict_andar3 = criaAtributoDistanciaParaCsv(pontosAlfa2Andar3, distanciasAndar3)

# %%
def criaStringEdgesCsv(dicionario, indexInicial):
    indexEdge = indexInicial
    for keyPrimaria in dicionario:
        for keyInterna in dicionario[keyPrimaria]:
            print('{},{},Undirected,{},,,{}'.format(keyPrimaria, keyInterna, round(dicionario[keyPrimaria][keyInterna], 1), indexEdge))
            indexEdge += 1
    return indexEdge

# %%
index_0 = criaStringEdgesCsv(dict_terreo, 41)
index_1 = criaStringEdgesCsv(dict_andar1, index_0)
index_2 = criaStringEdgesCsv(dict_andar2, index_1)
index_3 = criaStringEdgesCsv(dict_andar3, index_2)
# Out:
# 28,30,Undirected,9.3,,,41
# 28,32,Undirected,14.8,,,42
# 28,33,Undirected,13.5,,,43
# 28,34,Undirected,10.0,,,44
# 28,35,Undirected,12.1,,,45
# 28,36,Undirected,2.9,,,46
# 28,37,Undirected,9.1,,,47
# 28,38,Undirected,14.9,,,48
# 28,41,Undirected,19.3,,,49
# 28,42,Undirected,10.0,,,50
# 28,43,Undirected,14.8,,,51
# 28,44,Undirected,18.7,,,52
# 29,39,Undirected,2.5,,,53
# 29,40,Undirected,7.7,,,54
# 29,41,Undirected,18.7,,,55
# 30,31,Undirected,16.8,,,56
# 30,32,Undirected,7.0,,,57
# 30,33,Undirected,8.0,,,58
# 30,34,Undirected,5.2,,,59
# 30,35,Undirected,4.1,,,60
# 30,36,Undirected,7.3,,,61
# 30,37,Undirected,7.9,,,62
# 30,42,Undirected,2.9,,,63
# 30,43,Undirected,16.1,,,64
# 31,32,Undirected,9.8,,,65
# 31,33,Undirected,10.7,,,66
# 31,34,Undirected,14.0,,,67
# 31,35,Undirected,12.8,,,68
# 31,42,Undirected,19.0,,,69
# 32,33,Undirected,3.7,,,70
# 32,34,Undirected,5.2,,,71
# 32,35,Undirected,2.9,,,72
# 32,36,Undirected,12.1,,,73
# 32,37,Undirected,14.7,,,74
# 32,42,Undirected,9.3,,,75
# 33,34,Undirected,3.5,,,76
# 33,35,Undirected,4.4,,,77
# 33,36,Undirected,10.6,,,78
# 33,37,Undirected,15.7,,,79
# 33,42,Undirected,10.8,,,80
# 34,35,Undirected,3.4,,,81
# 34,36,Undirected,7.2,,,82
# 34,37,Undirected,12.5,,,83
# 34,42,Undirected,8.2,,,84
# 35,36,Undirected,9.5,,,85
# 35,37,Undirected,12.0,,,86
# 35,42,Undirected,6.7,,,87
# 36,37,Undirected,9.6,,,88
# 36,38,Undirected,17.8,,,89
# 36,42,Undirected,8.7,,,90
# 36,43,Undirected,16.5,,,91
# 37,38,Undirected,16.3,,,92
# 37,41,Undirected,17.0,,,93
# 37,42,Undirected,5.5,,,94
# 37,43,Undirected,8.3,,,95
# 37,44,Undirected,15.2,,,96
# 38,41,Undirected,7.3,,,97
# 38,43,Undirected,12.9,,,98
# 38,44,Undirected,8.9,,,99
# 39,40,Undirected,8.1,,,100
# 39,41,Undirected,18.8,,,101
# 41,43,Undirected,10.2,,,102
# 41,44,Undirected,2.7,,,103
# 42,43,Undirected,13.7,,,104
# 43,44,Undirected,7.9,,,105
# 45,46,Undirected,14.5,,,106
# 45,47,Undirected,7.4,,,107
# 45,51,Undirected,19.4,,,108
# 45,54,Undirected,12.9,,,109
# 46,51,Undirected,5.1,,,110
# 46,52,Undirected,7.8,,,111
# 46,53,Undirected,14.7,,,112
# 46,54,Undirected,1.6,,,113
# 48,49,Undirected,13.3,,,114
# 48,50,Undirected,7.9,,,115
# 49,50,Undirected,6.1,,,116
# 49,55,Undirected,10.3,,,117
# 50,55,Undirected,15.7,,,118
# 51,52,Undirected,3.1,,,119
# 51,53,Undirected,9.6,,,120
# 51,54,Undirected,6.7,,,121
# 52,53,Undirected,7.1,,,122
# 52,54,Undirected,9.3,,,123
# 52,55,Undirected,18.9,,,124
# 53,54,Undirected,16.2,,,125
# 53,55,Undirected,11.9,,,126
# 56,57,Undirected,12.9,,,127
# 56,58,Undirected,10.3,,,128
# 56,59,Undirected,6.5,,,129
# 56,60,Undirected,4.3,,,130
# 56,61,Undirected,15.7,,,131
# 56,62,Undirected,10.0,,,132
# 56,63,Undirected,12.3,,,133
# 56,64,Undirected,3.2,,,134
# 56,65,Undirected,7.1,,,135
# 56,66,Undirected,16.1,,,136
# 56,67,Undirected,1.1,,,137
# 56,68,Undirected,5.4,,,138
# 57,58,Undirected,2.9,,,139
# 57,59,Undirected,6.6,,,140
# 57,60,Undirected,8.8,,,141
# 57,64,Undirected,9.7,,,142
# 57,65,Undirected,6.0,,,143
# 57,66,Undirected,3.2,,,144
# 57,67,Undirected,13.3,,,145
# 57,68,Undirected,18.3,,,146
# 58,59,Undirected,3.8,,,147
# 58,60,Undirected,6.0,,,148
# 58,64,Undirected,7.1,,,149
# 58,65,Undirected,3.2,,,150
# 58,66,Undirected,6.0,,,151
# 58,67,Undirected,10.5,,,152
# 58,68,Undirected,15.5,,,153
# 59,60,Undirected,2.2,,,154
# 59,62,Undirected,16.4,,,155
# 59,63,Undirected,18.6,,,156
# 59,64,Undirected,3.4,,,157
# 59,65,Undirected,0.6,,,158
# 59,66,Undirected,9.8,,,159
# 59,67,Undirected,6.7,,,160
# 59,68,Undirected,11.7,,,161
# 60,61,Undirected,19.9,,,162
# 60,62,Undirected,14.2,,,163
# 60,63,Undirected,16.5,,,164
# 60,64,Undirected,1.5,,,165
# 60,65,Undirected,2.8,,,166
# 60,66,Undirected,12.0,,,167
# 60,67,Undirected,4.5,,,168
# 60,68,Undirected,9.5,,,169
# 61,62,Undirected,5.7,,,170
# 61,63,Undirected,3.6,,,171
# 61,64,Undirected,18.9,,,172
# 61,67,Undirected,15.4,,,173
# 61,68,Undirected,10.4,,,174
# 62,63,Undirected,2.6,,,175
# 62,64,Undirected,13.2,,,176
# 62,65,Undirected,17.0,,,177
# 62,67,Undirected,9.7,,,178
# 62,68,Undirected,4.7,,,179
# 63,64,Undirected,15.5,,,180
# 63,65,Undirected,19.3,,,181
# 63,67,Undirected,11.9,,,182
# 63,68,Undirected,6.9,,,183
# 64,65,Undirected,4.0,,,184
# 64,66,Undirected,12.9,,,185
# 64,67,Undirected,3.7,,,186
# 64,68,Undirected,8.6,,,187
# 65,66,Undirected,9.2,,,188
# 65,67,Undirected,7.3,,,189
# 65,68,Undirected,12.3,,,190
# 66,67,Undirected,16.5,,,191
# 67,68,Undirected,5.0,,,192
# 69,70,Undirected,19.7,,,193
# 69,75,Undirected,10.5,,,194
# 69,76,Undirected,12.7,,,195
# 69,78,Undirected,10.5,,,196
# 69,79,Undirected,4.1,,,197
# 69,80,Undirected,5.6,,,198
# 70,72,Undirected,3.4,,,199
# 70,73,Undirected,9.1,,,200
# 70,76,Undirected,7.0,,,201
# 70,77,Undirected,15.1,,,202
# 70,78,Undirected,9.3,,,203
# 70,80,Undirected,14.6,,,204
# 71,75,Undirected,13.9,,,205
# 72,73,Undirected,6.6,,,206
# 72,76,Undirected,9.5,,,207
# 72,77,Undirected,13.2,,,208
# 72,78,Undirected,11.1,,,209
# 72,80,Undirected,16.9,,,210
# 73,76,Undirected,16.0,,,211
# 73,77,Undirected,6.8,,,212
# 73,78,Undirected,17.7,,,213
# 74,77,Undirected,14.5,,,214
# 75,79,Undirected,7.1,,,215
# 75,80,Undirected,15.0,,,216
# 76,78,Undirected,3.2,,,217
# 76,79,Undirected,15.5,,,218
# 76,80,Undirected,7.5,,,219
# 78,79,Undirected,13.7,,,220
# 78,80,Undirected,6.1,,,221
# 79,80,Undirected,7.9,,,222
